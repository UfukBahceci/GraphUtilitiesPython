# %%
import sys
#sys.path.append("<InstallPath>\GraphUtilitiesPython")
#To avoid character encoding issues:
#for example, you can use "\U" instead of "U"
#or simply replace all "\" by "\\"
#for example,
sys.path.append("C:\\Users\\user\\GraphUtilitiesPython")

# %%
import numpy as np
from graphutilitiespy import Drawing
from graphutilitiespy import Graphs

# %%
vertices = np.array([[0, 0],
                     [0, 1],
                     [1, 0],
                     [1, 1]])
nodepos = np.array([[0, 0],
                     [0, 1],
                     [1, 0],
                     [1, 1]])
distancetype = 'Rectilinear'
#distancetype = 'Euclidian'
#distancetype = 'Chebyshev'
#distancetype = 'Cosine'
#distancetype = 'binaryJaccard'
#distancetype = 'binarySorensenDice'
#distancetype = 'discreteHellinger'
#distancetype = 'discreteKL'
#distancetype = 'binaryHamming'
drawnodes = True
writeedgelabels = True
G1 = Drawing.draw_completesimplegraph(vertices, nodepos, distancetype, drawnodes, writeedgelabels)
# Out:
# Rectilinear distance selected..
#
# Creating a complete simple graph..
#
# Drawing a complete simple graph..

# %%
sizeoffirstvertexset = 2
G2 = Drawing.draw_bipartitesimplegraph(vertices, nodepos, distancetype, sizeoffirstvertexset, drawnodes, writeedgelabels)
# Out:
# Rectilinear distance selected..
#
# Creating a bipartite simple graph..
#
# Drawing a bipartite simple graph..
